# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
file = pd.read_csv(r"C:\Users\ASUS\Downloads\advertising.csv")

# %%
#data analysis

file.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
file.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sns.boxplot(file)
# Out:
# <Axes: >

# %%
sns.heatmap(file.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=file[['TV','Radio','Newspaper']]
y=file['Sales']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
y_test.shape
# Out:
# (40,)

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

model.fit(X_train,y_train)


print(model.intercept_)
list(zip(X,model.coef_))
# Out:
# 4.773205203269834
# [('TV', 0.05368005507002438),
#  ('Radio', 0.11152623638588735),
#  ('Newspaper', -0.0035116615731400624)]

# %%
y_pred  = model.predict(X_test)

# %%
diff_file = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
diff_file
# Out:
#      Actual  Predicted
# 18     11.3  10.709889
# 170     8.4   8.686298
# 107    12.0   9.577870
# 98     25.4  24.862080
# 177    16.7  14.655845
# 182     8.7   8.321427
# 5       7.2  10.430480
# 146    18.2  18.445376
# 12      9.2   9.733943
# 152    16.6  17.929080
# 61     24.2  23.369886
# 125    10.6  10.679164
# 180    15.5  13.440323
# 154    20.6  17.174162
# 80     11.8  11.773802
# 7      13.2  13.370727
# 33     17.4  21.260099
# 130     1.6   9.196669
# 37     14.7  14.132018
# 74     17.0  18.926072
# 183    26.2  24.755080
# 145    10.3  12.484812
# 45     16.1  16.571306
# 159    12.9  13.773448
# 60      8.1   7.792991
# 123    15.2  15.196483
# 179    17.6  14.716079
# 185    22.6  20.738621
# 122    16.6  17.010419
# 44      8.5   8.834744
# 16     12.5  12.094244
# 55     23.7  20.748865
# 150    16.1  21.261480
# 111    21.8  21.904201
# 22      5.6   7.080871
# 189     6.7   7.044317
# 129     9.7   9.159499
# 4      17.9  15.477961
# 83     13.6  13.282823
# ...

# %%
from sklearn import  metrics

print('R squared: {:.2f}'.format(model.score(X,y)*100))
#The value of R Square is 90.11, which indicates that 90.11% of the data fit the regression model.

#Mean Square Error: Mean Square Error is calculated by taking the average of the square of the 
# difference between the original and predicted values of the data. The 
# lower the value, the better is the model’s performance. 
# The mean square error obtained for this particular model is 2.636, which is pretty good.
meansqrerror = metrics.mean_squared_error(y_test,y_pred)
print(meansqrerror)
# Out:
# R squared: 90.21
# 4.522552562041287
